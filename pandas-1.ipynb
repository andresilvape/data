# %%
# Utilizando Pandas
import pandas as pd

# %%
#importar arquivo para leitura
df = pd.read_csv("data_set.csv")

# %%
#visualizar 5 primeiras linhas
df.head()
# Out:
#                no_cidade                nome_da_cidade   gid       valor  taxa
# 0  Alta Floresta D'Oeste  <i>Alta Floresta D'Oeste</i>  6818  <b>110</b>   110
# 1              Ariquemes              <i>Ariquemes</i>  6819   <b>62</b>    62
# 2                 Cabixi                 <i>Cabixi</i>  6820  <b>115</b>   115
# 3                 Cacoal                 <i>Cacoal</i>  6821   <b>66</b>    66
# 4             Cerejeiras             <i>Cerejeiras</i>  6822  <b>109</b>   109

# %%
# Visualizar a 5 linhas finais
df.tail()
# Out:
#            no_cidade         nome_da_cidade   gid      valor  taxa
# 5565      Vianópolis      <i>Vianópolis</i>  7683  <b>98</b>    98
# 5566  Vicentinópolis  <i>Vicentinópolis</i>  7684  <b>96</b>    96
# 5567        Vila Boa        <i>Vila Boa</i>  7685  <b>93</b>    93
# 5568   Vila Propício   <i>Vila Propício</i>  7686  <b>97</b>    97
# 5569        Brasília        <i>Brasília</i>  5573  <b>14</b>    14

# %%
#total de linhas e Colunas
df.shape
# Out:
# (5570, 5)

# %%
#apenas nome das colunas
df.columns
# Out:
# Index(['no_cidade', 'nome_da_cidade', 'gid', 'valor', 'taxa'], dtype='object')

# %%
#tipo dos dados
df.dtypes
# Out:
# no_cidade         object
# nome_da_cidade    object
# gid                int64
# valor             object
# taxa               int64
# dtype: object

# %%
df.head()
# Out:
#                no_cidade                nome_da_cidade   gid       valor  taxa
# 0  Alta Floresta D'Oeste  <i>Alta Floresta D'Oeste</i>  6818  <b>110</b>   110
# 1              Ariquemes              <i>Ariquemes</i>  6819   <b>62</b>    62
# 2                 Cabixi                 <i>Cabixi</i>  6820  <b>115</b>   115
# 3                 Cacoal                 <i>Cacoal</i>  6821   <b>66</b>    66
# 4             Cerejeiras             <i>Cerejeiras</i>  6822  <b>109</b>   109

# %%
#Renomear colunas
df.rename(columns={"no_cidade":"cidade"})
# Out:
#                      cidade                nome_da_cidade   gid       valor  \
# 0     Alta Floresta D'Oeste  <i>Alta Floresta D'Oeste</i>  6818  <b>110</b>
# 1                 Ariquemes              <i>Ariquemes</i>  6819   <b>62</b>
# 2                    Cabixi                 <i>Cabixi</i>  6820  <b>115</b>
# 3                    Cacoal                 <i>Cacoal</i>  6821   <b>66</b>
# 4                Cerejeiras             <i>Cerejeiras</i>  6822  <b>109</b>
# ...                     ...                           ...   ...         ...
# 5565             Vianópolis             <i>Vianópolis</i>  7683   <b>98</b>
# 5566         Vicentinópolis         <i>Vicentinópolis</i>  7684   <b>96</b>
# 5567               Vila Boa               <i>Vila Boa</i>  7685   <b>93</b>
# 5568          Vila Propício          <i>Vila Propício</i>  7686   <b>97</b>
# 5569               Brasília               <i>Brasília</i>  5573   <b>14</b>
#
#       taxa
# 0      110
# 1       62
# 2      115
# ...

# %%
#Retorna estatisticas
df.describe()
# Out:
#                 gid         taxa
# count   5570.000000  5570.000000
# mean    8357.500000    89.774147
# std     1608.064831    22.523298
# min     5573.000000     0.000000
# 25%     6965.250000    93.000000
# 50%     8357.500000    99.000000
# 75%     9749.750000   101.000000
# max    11142.000000   147.000000
